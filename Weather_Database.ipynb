# %%
# Importing the randon module
import random

# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
#lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates  = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities= []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 721

# %%
# Import the requests library.
import requests

# Import the API key.
from conf import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
import pprint

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
#     print(city_url)
#     break

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
#         pprint.pprint(city_weather)
#         break
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tromso
# Processing Record 2 of Set 1 | wonthaggi
# Processing Record 3 of Set 1 | cap malheureux
# Processing Record 4 of Set 1 | half moon bay
# Processing Record 5 of Set 1 | asyut
# Processing Record 6 of Set 1 | norman wells
# Processing Record 7 of Set 1 | vanavara
# Processing Record 8 of Set 1 | sainte-suzanne
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | mariental
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | riberalta
# Processing Record 20 of Set 1 | lavrentiya
# Processing Record 21 of Set 1 | batemans bay
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | erzin
# Processing Record 24 of Set 1 | talcahuano
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | tieli
# Processing Record 27 of Set 1 | sept-iles
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 1 | virginia beach
# Processing Record 31 of Set 1 | jiuquan
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | ambunti
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | shache
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 1 | mahebourg
# Processing Record 39 of Set 1 | cherskiy
# Processing Record 40 of Set 1 | constitucion
# Processing Record 41 of Set 1 | parichhatgarh
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | sabha
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | clyde river
# Processing Record 48 of Set 1 | airai
# Processing Record 49 of Set 1 | santa maria
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | cabo san lucas
# Processing Record 2 of Set 2 | santa isabel do rio negro
# Processing Record 3 of Set 2 | japura
# Processing Record 4 of Set 2 | tonekabon
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 7 of Set 2 | pisco
# Processing Record 8 of Set 2 | tuatapere
# Processing Record 9 of Set 2 | wanaka
# Processing Record 10 of Set 2 | boden
# Processing Record 11 of Set 2 | aklavik
# Processing Record 12 of Set 2 | saskylakh
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | ilulissat
# Processing Record 15 of Set 2 | omboue
# Processing Record 16 of Set 2 | tjome
# Processing Record 17 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 2 | vila franca do campo
# Processing Record 19 of Set 2 | talnakh
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | tazovskiy
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | muli
# Processing Record 24 of Set 2 | hengyang
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | zhigansk
# Processing Record 27 of Set 2 | channel-port aux basques
# Processing Record 28 of Set 2 | boysun
# Processing Record 29 of Set 2 | araouane
# Processing Record 30 of Set 2 | christchurch
# Processing Record 31 of Set 2 | ponta do sol
# Processing Record 32 of Set 2 | aktau
# Processing Record 33 of Set 2 | tuktoyaktuk
# Processing Record 34 of Set 2 | provideniya
# Processing Record 35 of Set 2 | aksarka
# Processing Record 36 of Set 2 | san cristobal
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | koslan
# Processing Record 39 of Set 2 | gamba
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | mackay
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | shenjiamen
# Processing Record 44 of Set 2 | bathsheba
# Processing Record 45 of Set 2 | bonito
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | toamasina
# Processing Record 48 of Set 2 | candido mendes
# Processing Record 49 of Set 2 | kristiinankaupunki
# Processing Record 50 of Set 2 | pimentel
# Processing Record 1 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 2 of Set 3 | sao joao da barra
# Processing Record 3 of Set 3 | lorengau
# Processing Record 4 of Set 3 | kaitangata
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | saint-francois
# Processing Record 7 of Set 3 | isangel
# Processing Record 8 of Set 3 | loughton
# Processing Record 9 of Set 3 | maragogi
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | torbay
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | asahikawa
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | butaritari
# Processing Record 17 of Set 3 | arlit
# Processing Record 18 of Set 3 | guerrero negro
# Processing Record 19 of Set 3 | northam
# Processing Record 20 of Set 3 | irmo
# Processing Record 21 of Set 3 | chokurdakh
# Processing Record 22 of Set 3 | saint-jean-de-maurienne
# Processing Record 23 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 3 | lata
# Processing Record 25 of Set 3 | skibbereen
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | saint-philippe
# Processing Record 28 of Set 3 | waipawa
# Processing Record 29 of Set 3 | caxito
# Processing Record 30 of Set 3 | tiarei
# Processing Record 31 of Set 3 | te anau
# Processing Record 32 of Set 3 | nyuksenitsa
# Processing Record 33 of Set 3 | loei
# Processing Record 34 of Set 3 | souillac
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | dekar
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | ribeira brava
# Processing Record 39 of Set 3 | sainte-marie
# Processing Record 40 of Set 3 | bluff
# Processing Record 41 of Set 3 | oksfjord
# Processing Record 42 of Set 3 | dingle
# Processing Record 43 of Set 3 | yaring
# Processing Record 44 of Set 3 | san patricio
# Processing Record 45 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 3 | ahipara
# Processing Record 47 of Set 3 | ugoofaaru
# Processing Record 48 of Set 3 | sakaiminato
# Processing Record 49 of Set 3 | hambantota
# Processing Record 50 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 1 of Set 4 | georgetown
# Processing Record 2 of Set 4 | faanui
# Processing Record 3 of Set 4 | asau
# Processing Record 4 of Set 4 | kodiak
# Processing Record 5 of Set 4 | okhotsk
# Processing Record 6 of Set 4 | namatanai
# Processing Record 7 of Set 4 | zenzeli
# Processing Record 8 of Set 4 | geraldton
# Processing Record 9 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 4 | elko
# Processing Record 11 of Set 4 | kruisfontein
# Processing Record 12 of Set 4 | vaini
# Processing Record 13 of Set 4 | katherine
# Processing Record 14 of Set 4 | chilliwack
# Processing Record 15 of Set 4 | rio gallegos
# Processing Record 16 of Set 4 | port lincoln
# Processing Record 17 of Set 4 | visby
# Processing Record 18 of Set 4 | sur
# Processing Record 19 of Set 4 | port alfred
# Processing Record 20 of Set 4 | grindavik
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | khatima
# Processing Record 23 of Set 4 | toowoomba
# Processing Record 24 of Set 4 | alta floresta
# Processing Record 25 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 4 | moerai
# Processing Record 27 of Set 4 | camopi
# Processing Record 28 of Set 4 | moose factory
# Processing Record 29 of Set 4 | neuquen
# Processing Record 30 of Set 4 | maceio
# Processing Record 31 of Set 4 | esperance
# Processing Record 32 of Set 4 | kristiansund
# Processing Record 33 of Set 4 | vestmanna
# Processing Record 34 of Set 4 | kathmandu
# Processing Record 35 of Set 4 | alzey
# Processing Record 36 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 4 | xghajra
# City not found. Skipping...
# Processing Record 38 of Set 4 | karpathos
# Processing Record 39 of Set 4 | brae
# Processing Record 40 of Set 4 | altay
# Processing Record 41 of Set 4 | roma
# Processing Record 42 of Set 4 | boa esperanca
# Processing Record 43 of Set 4 | saldanha
# Processing Record 44 of Set 4 | tezu
# Processing Record 45 of Set 4 | ankang
# Processing Record 46 of Set 4 | lompoc
# Processing Record 47 of Set 4 | mandalgovi
# Processing Record 48 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 4 | cayenne
# Processing Record 50 of Set 4 | nikolayevskaya
# Processing Record 1 of Set 5 | filadelfia
# Processing Record 2 of Set 5 | nampula
# Processing Record 3 of Set 5 | san matias
# Processing Record 4 of Set 5 | tigzirt
# Processing Record 5 of Set 5 | hirara
# Processing Record 6 of Set 5 | ataco
# Processing Record 7 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 5 | inongo
# Processing Record 9 of Set 5 | caravelas
# Processing Record 10 of Set 5 | florida
# Processing Record 11 of Set 5 | nome
# Processing Record 12 of Set 5 | avera
# Processing Record 13 of Set 5 | yulara
# Processing Record 14 of Set 5 | nishihara
# Processing Record 15 of Set 5 | katsuura
# Processing Record 16 of Set 5 | iqaluit
# Processing Record 17 of Set 5 | aswan
# Processing Record 18 of Set 5 | barrow
# Processing Record 19 of Set 5 | arraial do cabo
# Processing Record 20 of Set 5 | chuy
# Processing Record 21 of Set 5 | chapais
# Processing Record 22 of Set 5 | ostrovnoy
# Processing Record 23 of Set 5 | high level
# Processing Record 24 of Set 5 | chacabuco
# Processing Record 25 of Set 5 | sabya
# Processing Record 26 of Set 5 | novolvovsk
# City not found. Skipping...
# Processing Record 27 of Set 5 | poum
# Processing Record 28 of Set 5 | bengkulu
# Processing Record 29 of Set 5 | quelimane
# Processing Record 30 of Set 5 | santiago de cao
# Processing Record 31 of Set 5 | lauingen
# Processing Record 32 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 33 of Set 5 | madingou
# Processing Record 34 of Set 5 | taveta
# Processing Record 35 of Set 5 | dunedin
# Processing Record 36 of Set 5 | tasiilaq
# Processing Record 37 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 5 | opuwo
# Processing Record 39 of Set 5 | hobyo
# Processing Record 40 of Set 5 | inverell
# Processing Record 41 of Set 5 | port-cartier
# Processing Record 42 of Set 5 | buenos aires
# Processing Record 43 of Set 5 | sukhobezvodnoye
# Processing Record 44 of Set 5 | revelstoke
# Processing Record 45 of Set 5 | port blair
# Processing Record 46 of Set 5 | sabang
# Processing Record 47 of Set 5 | jardim
# Processing Record 48 of Set 5 | locri
# Processing Record 49 of Set 5 | saint stephen
# Processing Record 50 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 6 | sidney
# Processing Record 2 of Set 6 | dumas
# Processing Record 3 of Set 6 | yarensk
# Processing Record 4 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 6 | tarakan
# Processing Record 6 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 6 | sao filipe
# Processing Record 8 of Set 6 | comodoro rivadavia
# Processing Record 9 of Set 6 | kiama
# Processing Record 10 of Set 6 | zabolotovka
# Processing Record 11 of Set 6 | cidreira
# Processing Record 12 of Set 6 | baganga
# Processing Record 13 of Set 6 | chadan
# Processing Record 14 of Set 6 | baghdad
# Processing Record 15 of Set 6 | korla
# Processing Record 16 of Set 6 | boende
# Processing Record 17 of Set 6 | challans
# Processing Record 18 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 19 of Set 6 | fortuna
# Processing Record 20 of Set 6 | la asuncion
# Processing Record 21 of Set 6 | coahuayana
# Processing Record 22 of Set 6 | edd
# Processing Record 23 of Set 6 | prince rupert
# Processing Record 24 of Set 6 | huilong
# Processing Record 25 of Set 6 | sitka
# Processing Record 26 of Set 6 | novobirilyussy
# Processing Record 27 of Set 6 | severo-yeniseyskiy
# Processing Record 28 of Set 6 | takoradi
# Processing Record 29 of Set 6 | benguela
# Processing Record 30 of Set 6 | sidi ali
# Processing Record 31 of Set 6 | sungairaya
# Processing Record 32 of Set 6 | manati
# Processing Record 33 of Set 6 | simpang
# Processing Record 34 of Set 6 | pevek
# Processing Record 35 of Set 6 | carnarvon
# Processing Record 36 of Set 6 | ontario
# Processing Record 37 of Set 6 | hami
# Processing Record 38 of Set 6 | college
# Processing Record 39 of Set 6 | berlevag
# Processing Record 40 of Set 6 | lagoa
# Processing Record 41 of Set 6 | dovbysh
# Processing Record 42 of Set 6 | dhidhdhoo
# Processing Record 43 of Set 6 | daly city
# Processing Record 44 of Set 6 | shingu
# Processing Record 45 of Set 6 | zhezkazgan
# Processing Record 46 of Set 6 | itoman
# Processing Record 47 of Set 6 | zhangye
# Processing Record 48 of Set 6 | lazaro cardenas
# Processing Record 49 of Set 6 | alofi
# Processing Record 50 of Set 6 | mandera
# Processing Record 1 of Set 7 | voyvozh
# Processing Record 2 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 7 | buchanan
# Processing Record 4 of Set 7 | boa vista
# Processing Record 5 of Set 7 | la rioja
# Processing Record 6 of Set 7 | los llanos de aridane
# Processing Record 7 of Set 7 | kidal
# Processing Record 8 of Set 7 | liepaja
# Processing Record 9 of Set 7 | mirik
# Processing Record 10 of Set 7 | brewster
# Processing Record 11 of Set 7 | yaan
# Processing Record 12 of Set 7 | vardo
# Processing Record 13 of Set 7 | paamiut
# Processing Record 14 of Set 7 | pochutla
# Processing Record 15 of Set 7 | noumea
# Processing Record 16 of Set 7 | dosso
# Processing Record 17 of Set 7 | jahangirpur
# Processing Record 18 of Set 7 | teknaf
# Processing Record 19 of Set 7 | townsville
# Processing Record 20 of Set 7 | husavik
# Processing Record 21 of Set 7 | nanortalik
# Processing Record 22 of Set 7 | male
# Processing Record 23 of Set 7 | cassilandia
# Processing Record 24 of Set 7 | tiksi
# Processing Record 25 of Set 7 | lososina
# Processing Record 26 of Set 7 | codrington
# Processing Record 27 of Set 7 | askiz
# Processing Record 28 of Set 7 | longfeng
# Processing Record 29 of Set 7 | tambovka
# Processing Record 30 of Set 7 | matay
# Processing Record 31 of Set 7 | egvekinot
# Processing Record 32 of Set 7 | bukan
# Processing Record 33 of Set 7 | lloydminster
# Processing Record 34 of Set 7 | mar del plata
# Processing Record 35 of Set 7 | pizarro
# Processing Record 36 of Set 7 | barentu
# Processing Record 37 of Set 7 | nantucket
# Processing Record 38 of Set 7 | meulaboh
# Processing Record 39 of Set 7 | mount isa
# Processing Record 40 of Set 7 | bilibino
# Processing Record 41 of Set 7 | whitehorse
# Processing Record 42 of Set 7 | upernavik
# Processing Record 43 of Set 7 | ossora
# Processing Record 44 of Set 7 | pangody
# Processing Record 45 of Set 7 | tura
# Processing Record 46 of Set 7 | kaeo
# Processing Record 47 of Set 7 | cockburn town
# Processing Record 48 of Set 7 | kahului
# Processing Record 49 of Set 7 | mirnyy
# Processing Record 50 of Set 7 | dabakala
# Processing Record 1 of Set 8 | puri
# Processing Record 2 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 3 of Set 8 | maryborough
# Processing Record 4 of Set 8 | vozhega
# Processing Record 5 of Set 8 | bambous virieux
# Processing Record 6 of Set 8 | popondetta
# Processing Record 7 of Set 8 | nisia floresta
# Processing Record 8 of Set 8 | novyy urgal
# Processing Record 9 of Set 8 | nizhniy tsasuchey
# Processing Record 10 of Set 8 | buala
# Processing Record 11 of Set 8 | saint-pierre
# Processing Record 12 of Set 8 | necochea
# Processing Record 13 of Set 8 | gizo
# Processing Record 14 of Set 8 | ahuimanu
# Processing Record 15 of Set 8 | narsaq
# Processing Record 16 of Set 8 | neiafu
# Processing Record 17 of Set 8 | mufumbwe
# Processing Record 18 of Set 8 | inhambane
# Processing Record 19 of Set 8 | luderitz
# Processing Record 20 of Set 8 | victor harbor
# Processing Record 21 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 8 | oranjemund
# Processing Record 23 of Set 8 | jacareacanga
# Processing Record 24 of Set 8 | chelno-vershiny
# Processing Record 25 of Set 8 | alekseyevsk
# Processing Record 26 of Set 8 | lebanon
# Processing Record 27 of Set 8 | rielasingen-worblingen
# Processing Record 28 of Set 8 | muros
# Processing Record 29 of Set 8 | sukumo
# Processing Record 30 of Set 8 | zhireken
# Processing Record 31 of Set 8 | reshetylivka
# Processing Record 32 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 33 of Set 8 | broken hill
# Processing Record 34 of Set 8 | nelson bay
# Processing Record 35 of Set 8 | manavgat
# Processing Record 36 of Set 8 | qaqortoq
# Processing Record 37 of Set 8 | tabas
# Processing Record 38 of Set 8 | henties bay
# Processing Record 39 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 8 | waiouru
# Processing Record 41 of Set 8 | boyolangu
# Processing Record 42 of Set 8 | grand-santi
# Processing Record 43 of Set 8 | batagay-alyta
# Processing Record 44 of Set 8 | manado
# Processing Record 45 of Set 8 | axim
# Processing Record 46 of Set 8 | wete
# Processing Record 47 of Set 8 | ternate
# Processing Record 48 of Set 8 | burica
# City not found. Skipping...
# Processing Record 49 of Set 8 | zlobin
# Processing Record 50 of Set 8 | north bend
# Processing Record 1 of Set 9 | yanji
# Processing Record 2 of Set 9 | coquimbo
# Processing Record 3 of Set 9 | bauska
# Processing Record 4 of Set 9 | kentau
# Processing Record 5 of Set 9 | itupiranga
# Processing Record 6 of Set 9 | tingi
# Processing Record 7 of Set 9 | yining
# Processing Record 8 of Set 9 | salinas
# Processing Record 9 of Set 9 | valparaiso
# Processing Record 10 of Set 9 | sijunjung
# Processing Record 11 of Set 9 | bowen
# Processing Record 12 of Set 9 | ranong
# Processing Record 13 of Set 9 | roald
# Processing Record 14 of Set 9 | atar
# Processing Record 15 of Set 9 | barroualie
# City not found. Skipping...
# Processing Record 16 of Set 9 | kirakira
# Processing Record 17 of Set 9 | hailar
# Processing Record 18 of Set 9 | alugan
# Processing Record 19 of Set 9 | santa vitoria do palmar
# Processing Record 20 of Set 9 | diego de almagro
# Processing Record 21 of Set 9 | belaya gora
# Processing Record 22 of Set 9 | ulladulla
# Processing Record 23 of Set 9 | vestbygda
# City not found. Skipping...
# Processing Record 24 of Set 9 | margate
# Processing Record 25 of Set 9 | shimanovsk
# Processing Record 26 of Set 9 | palaiokhora
# City not found. Skipping...
# Processing Record 27 of Set 9 | porto santo
# Processing Record 28 of Set 9 | klaksvik
# Processing Record 29 of Set 9 | makungu
# Processing Record 30 of Set 9 | leshukonskoye
# Processing Record 31 of Set 9 | mackenzie
# Processing Record 32 of Set 9 | makaryev
# Processing Record 33 of Set 9 | jumla
# Processing Record 34 of Set 9 | port hedland
# Processing Record 35 of Set 9 | sisophon
# Processing Record 36 of Set 9 | rio muerto
# Processing Record 37 of Set 9 | haines junction
# Processing Record 38 of Set 9 | yarkovo
# Processing Record 39 of Set 9 | el tigre
# Processing Record 40 of Set 9 | bacolod
# Processing Record 41 of Set 9 | pontivy
# Processing Record 42 of Set 9 | bardiyah
# Processing Record 43 of Set 9 | kavieng
# Processing Record 44 of Set 9 | laguna
# Processing Record 45 of Set 9 | montrose
# Processing Record 46 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 9 | marzuq
# Processing Record 48 of Set 9 | narodychi
# Processing Record 49 of Set 9 | kamenka
# Processing Record 50 of Set 9 | beeville
# Processing Record 1 of Set 10 | ballina
# Processing Record 2 of Set 10 | anjiang
# Processing Record 3 of Set 10 | dauriya
# Processing Record 4 of Set 10 | coihaique
# Processing Record 5 of Set 10 | horta
# Processing Record 6 of Set 10 | beringovskiy
# Processing Record 7 of Set 10 | zacualtipan
# Processing Record 8 of Set 10 | flinders
# Processing Record 9 of Set 10 | el cope
# Processing Record 10 of Set 10 | morros
# Processing Record 11 of Set 10 | sonqor
# Processing Record 12 of Set 10 | samana
# Processing Record 13 of Set 10 | sakaraha
# Processing Record 14 of Set 10 | hasaki
# Processing Record 15 of Set 10 | mashhad
# Processing Record 16 of Set 10 | urumqi
# Processing Record 17 of Set 10 | natal
# Processing Record 18 of Set 10 | finschhafen
# Processing Record 19 of Set 10 | torrington
# Processing Record 20 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 10 | wuwei
# Processing Record 22 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 10 | shitanjing
# Processing Record 24 of Set 10 | kasongo
# Processing Record 25 of Set 10 | awjilah
# Processing Record 26 of Set 10 | kakonko
# Processing Record 27 of Set 10 | country club
# Processing Record 28 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 10 | mecca
# Processing Record 30 of Set 10 | pak phanang
# Processing Record 31 of Set 10 | palauig
# Processing Record 32 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 10 | mocuba
# Processing Record 34 of Set 10 | rorvik
# Processing Record 35 of Set 10 | saint-georges
# Processing Record 36 of Set 10 | viedma
# Processing Record 37 of Set 10 | kaseda
# Processing Record 38 of Set 10 | la ronge
# Processing Record 39 of Set 10 | aqtobe
# Processing Record 40 of Set 10 | saint-augustin
# Processing Record 41 of Set 10 | balikpapan
# Processing Record 42 of Set 10 | matagami
# Processing Record 43 of Set 10 | puerto escondido
# Processing Record 44 of Set 10 | yashan
# Processing Record 45 of Set 10 | doume
# Processing Record 46 of Set 10 | chifeng
# Processing Record 47 of Set 10 | fort nelson
# Processing Record 48 of Set 10 | zhangjiakou
# Processing Record 49 of Set 10 | tsaghkahovit
# Processing Record 50 of Set 10 | sinnamary
# Processing Record 1 of Set 11 | kibuye
# Processing Record 2 of Set 11 | lagos
# Processing Record 3 of Set 11 | ratholo
# Processing Record 4 of Set 11 | sturgis
# Processing Record 5 of Set 11 | gigmoto
# Processing Record 6 of Set 11 | aquiraz
# Processing Record 7 of Set 11 | komsomolskiy
# Processing Record 8 of Set 11 | kinkala
# Processing Record 9 of Set 11 | tokzar
# City not found. Skipping...
# Processing Record 10 of Set 11 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 11 of Set 11 | shimoda
# Processing Record 12 of Set 11 | bani walid
# Processing Record 13 of Set 11 | ilheus
# Processing Record 14 of Set 11 | sungaipenuh
# Processing Record 15 of Set 11 | mildura
# Processing Record 16 of Set 11 | dudinka
# Processing Record 17 of Set 11 | anloga
# Processing Record 18 of Set 11 | tanshui
# City not found. Skipping...
# Processing Record 19 of Set 11 | suihua
# Processing Record 20 of Set 11 | ancud
# Processing Record 21 of Set 11 | nuevo progreso
# Processing Record 22 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 11 | vestmannaeyjar
# Processing Record 24 of Set 11 | kulhudhuffushi
# Processing Record 25 of Set 11 | alejandria
# Processing Record 26 of Set 11 | pucallpa
# Processing Record 27 of Set 11 | cascas
# Processing Record 28 of Set 11 | mastic
# Processing Record 29 of Set 11 | marawi
# Processing Record 30 of Set 11 | saint-leger
# Processing Record 31 of Set 11 | qianan
# Processing Record 32 of Set 11 | kibaya
# Processing Record 33 of Set 11 | labrea
# Processing Record 34 of Set 11 | riyadh
# Processing Record 35 of Set 11 | awbari
# Processing Record 36 of Set 11 | demba
# Processing Record 37 of Set 11 | nogent-le-rotrou
# Processing Record 38 of Set 11 | jucurutu
# Processing Record 39 of Set 11 | savalou
# Processing Record 40 of Set 11 | kaoma
# Processing Record 41 of Set 11 | husum
# Processing Record 42 of Set 11 | turukhansk
# Processing Record 43 of Set 11 | tessalit
# Processing Record 44 of Set 11 | yialos
# City not found. Skipping...
# Processing Record 45 of Set 11 | canavieiras
# Processing Record 46 of Set 11 | muisne
# Processing Record 47 of Set 11 | havre-saint-pierre
# Processing Record 48 of Set 11 | ladnun
# Processing Record 49 of Set 11 | wukari
# Processing Record 50 of Set 11 | pingliang
# Processing Record 1 of Set 12 | kalmunai
# Processing Record 2 of Set 12 | touros
# Processing Record 3 of Set 12 | dire dawa
# Processing Record 4 of Set 12 | yerbogachen
# Processing Record 5 of Set 12 | ayna
# Processing Record 6 of Set 12 | bonthe
# Processing Record 7 of Set 12 | kloulklubed
# Processing Record 8 of Set 12 | reno
# Processing Record 9 of Set 12 | portland
# Processing Record 10 of Set 12 | djibo
# Processing Record 11 of Set 12 | lima
# Processing Record 12 of Set 12 | barghat
# Processing Record 13 of Set 12 | alekseyevskoye
# Processing Record 14 of Set 12 | huangpu
# Processing Record 15 of Set 12 | deer lake
# Processing Record 16 of Set 12 | broome
# Processing Record 17 of Set 12 | ust-kut
# Processing Record 18 of Set 12 | rogun
# City not found. Skipping...
# Processing Record 19 of Set 12 | vao
# Processing Record 20 of Set 12 | pitimbu
# Processing Record 21 of Set 12 | karratha
# Processing Record 22 of Set 12 | duz
# City not found. Skipping...
# Processing Record 23 of Set 12 | aranos
# Processing Record 24 of Set 12 | marsh harbour
# Processing Record 25 of Set 12 | mbandaka
# Processing Record 26 of Set 12 | tuy hoa
# Processing Record 27 of Set 12 | kawalu
# Processing Record 28 of Set 12 | westport
# Processing Record 29 of Set 12 | seoul
# Processing Record 30 of Set 12 | baykit
# Processing Record 31 of Set 12 | kutum
# Processing Record 32 of Set 12 | salalah
# Processing Record 33 of Set 12 | anuradhapura
# Processing Record 34 of Set 12 | kuusamo
# Processing Record 35 of Set 12 | urusha
# Processing Record 36 of Set 12 | rabaul
# Processing Record 37 of Set 12 | shorewood
# Processing Record 38 of Set 12 | humble
# Processing Record 39 of Set 12 | san bartolome de tirajana
# Processing Record 40 of Set 12 | sehithwa
# Processing Record 41 of Set 12 | ixtapa
# Processing Record 42 of Set 12 | nenjiang
# Processing Record 43 of Set 12 | buxton
# Processing Record 44 of Set 12 | dunmore east
# Processing Record 45 of Set 12 | ust-tsilma
# Processing Record 46 of Set 12 | esmeraldas
# Processing Record 47 of Set 12 | san jeronimo
# Processing Record 48 of Set 12 | inta
# Processing Record 49 of Set 12 | bucerias
# Processing Record 50 of Set 12 | vilhena
# Processing Record 1 of Set 13 | drabiv
# Processing Record 2 of Set 13 | sao gabriel da cachoeira
# Processing Record 3 of Set 13 | leningradskiy
# Processing Record 4 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 13 | san carlos de bariloche
# Processing Record 6 of Set 13 | amboasary
# Processing Record 7 of Set 13 | satuk
# Processing Record 8 of Set 13 | rawson
# Processing Record 9 of Set 13 | danane
# Processing Record 10 of Set 13 | pierre
# Processing Record 11 of Set 13 | hay river
# Processing Record 12 of Set 13 | tucuman
# Processing Record 13 of Set 13 | goderich
# Processing Record 14 of Set 13 | rio grande
# Processing Record 15 of Set 13 | camacari
# Processing Record 16 of Set 13 | yeppoon
# Processing Record 17 of Set 13 | dali
# Processing Record 18 of Set 13 | port hardy
# Processing Record 19 of Set 13 | trairi
# Processing Record 20 of Set 13 | sikonge
# Processing Record 21 of Set 13 | zaranj
# Processing Record 22 of Set 13 | puerto leguizamo
# Processing Record 23 of Set 13 | anse-bertrand
# Processing Record 24 of Set 13 | bouna
# Processing Record 25 of Set 13 | fare
# Processing Record 26 of Set 13 | kibala
# Processing Record 27 of Set 13 | sioux lookout
# Processing Record 28 of Set 13 | virtsu
# Processing Record 29 of Set 13 | waverly
# Processing Record 30 of Set 13 | macaubas
# Processing Record 31 of Set 13 | mekhelta
# City not found. Skipping...
# Processing Record 32 of Set 13 | porto novo
# Processing Record 33 of Set 13 | ambon
# Processing Record 34 of Set 13 | eureka
# Processing Record 35 of Set 13 | gambela
# Processing Record 36 of Set 13 | ketchikan
# Processing Record 37 of Set 13 | port keats
# Processing Record 38 of Set 13 | tarrafal
# Processing Record 39 of Set 13 | panixtlahuaca
# City not found. Skipping...
# Processing Record 40 of Set 13 | san quintin
# Processing Record 41 of Set 13 | nizhniy kuranakh
# Processing Record 42 of Set 13 | krutikha
# Processing Record 43 of Set 13 | port hawkesbury
# Processing Record 44 of Set 13 | fengrun
# Processing Record 45 of Set 13 | fairbanks
# Processing Record 46 of Set 13 | sayat
# Processing Record 47 of Set 13 | harper
# Processing Record 48 of Set 13 | vostok
# Processing Record 49 of Set 13 | yar-sale
# Processing Record 50 of Set 13 | koboldo
# City not found. Skipping...
# Processing Record 1 of Set 14 | matadi
# Processing Record 2 of Set 14 | rapid valley
# Processing Record 3 of Set 14 | dolores
# Processing Record 4 of Set 14 | biltine
# Processing Record 5 of Set 14 | plettenberg bay
# Processing Record 6 of Set 14 | marsabit
# Processing Record 7 of Set 14 | abong mbang
# Processing Record 8 of Set 14 | chapleau
# Processing Record 9 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 10 of Set 14 | ambilobe
# Processing Record 11 of Set 14 | galveston
# Processing Record 12 of Set 14 | luchegorsk
# Processing Record 13 of Set 14 | olafsvik
# Processing Record 14 of Set 14 | hutchinson
# Processing Record 15 of Set 14 | othonoi
# City not found. Skipping...
# Processing Record 16 of Set 14 | roebourne
# Processing Record 17 of Set 14 | kadhan
# Processing Record 18 of Set 14 | mayskiy
# Processing Record 19 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 20 of Set 14 | tilichiki
# Processing Record 21 of Set 14 | maniitsoq
# Processing Record 22 of Set 14 | mitsamiouli
# Processing Record 23 of Set 14 | ciudad bolivar
# Processing Record 24 of Set 14 | nokaneng
# Processing Record 25 of Set 14 | manggar
# Processing Record 26 of Set 14 | les escoumins
# Processing Record 27 of Set 14 | hovd
# Processing Record 28 of Set 14 | lonar
# Processing Record 29 of Set 14 | vulcan
# Processing Record 30 of Set 14 | poya
# Processing Record 31 of Set 14 | mirskoy
# Processing Record 32 of Set 14 | bollnas
# Processing Record 33 of Set 14 | clarksburg
# Processing Record 34 of Set 14 | iquique
# Processing Record 35 of Set 14 | sri aman
# Processing Record 36 of Set 14 | klyuchi
# Processing Record 37 of Set 14 | carauari
# Processing Record 38 of Set 14 | morondava
# Processing Record 39 of Set 14 | nuevo casas grandes
# Processing Record 40 of Set 14 | licheng
# Processing Record 41 of Set 14 | reconquista
# Processing Record 42 of Set 14 | khrebtovaya
# Processing Record 43 of Set 14 | ploemeur
# Processing Record 44 of Set 14 | cartagena
# Processing Record 45 of Set 14 | goshen
# Processing Record 46 of Set 14 | dom pedrito
# Processing Record 47 of Set 14 | innisfail
# Processing Record 48 of Set 14 | lai
# Processing Record 49 of Set 14 | piracicaba
# Processing Record 50 of Set 14 | bogorodskoye
# Processing Record 1 of Set 15 | rapar
# Processing Record 2 of Set 15 | laiagam
# City not found. Skipping...
# Processing Record 3 of Set 15 | bedele
# Processing Record 4 of Set 15 | talaya
# Processing Record 5 of Set 15 | emerald
# Processing Record 6 of Set 15 | oktyabrskiy
# Processing Record 7 of Set 15 | uruzgan
# Processing Record 8 of Set 15 | iskateley
# Processing Record 9 of Set 15 | ajdabiya
# Processing Record 10 of Set 15 | velikodvorskiy
# Processing Record 11 of Set 15 | namibe
# Processing Record 12 of Set 15 | milkovo
# Processing Record 13 of Set 15 | quatre cocos
# Processing Record 14 of Set 15 | warrensburg
# Processing Record 15 of Set 15 | feira
# Processing Record 16 of Set 15 | axixa do tocantins
# City not found. Skipping...
# Processing Record 17 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 18 of Set 15 | olavarria
# Processing Record 19 of Set 15 | burns lake
# Processing Record 20 of Set 15 | shelburne
# Processing Record 21 of Set 15 | namanga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Tromso  69.6496   18.9570     17.62        73           0
# 1       Wonthaggi -38.6044  145.5913     80.94        56         100
# 2  Cap Malheureux -19.9842   57.6142     81.46        70          32
# 3   Half Moon Bay  37.4636 -122.4286     56.71        91          90
# 4           Asyut  27.1810   31.1837     56.34        67          97
# 5    Norman Wells  65.2820 -126.8329    -12.89        80          46
# 6        Vanavara  60.3400  102.2797     -6.65        97         100
# 7  Sainte-Suzanne -20.9061   55.6089     84.38        62           0
# 8            Hilo  19.7297 -155.0900     74.93        90          75
# 9         Ushuaia -54.8000  -68.3000     44.26        61          20
#
#    Wind Speed Country Current Description
# 0        1.99      NO           clear sky
# 1        5.82      AU          light rain
# 2        7.00      MU    scattered clouds
# 3        6.91      US                mist
# 4        4.18      EG     overcast clouds
# 5        5.08      CA    scattered clouds
# 6        1.88      RU     overcast clouds
# 7       18.41      RE           clear sky
# 8        9.22      US       moderate rain
# 9       23.02      AR          few clouds

# %%
#change order of columns
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_order]
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Tromso      NO  69.6496   18.9570     17.62        73           0
# 1       Wonthaggi      AU -38.6044  145.5913     80.94        56         100
# 2  Cap Malheureux      MU -19.9842   57.6142     81.46        70          32
# 3   Half Moon Bay      US  37.4636 -122.4286     56.71        91          90
# 4           Asyut      EG  27.1810   31.1837     56.34        67          97
#
#    Wind Speed Current Description
# 0        1.99           clear sky
# 1        5.82          light rain
# 2        7.00    scattered clouds
# 3        6.91                mist
# 4        4.18     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_DataBase.csv"
# Export the Data Frame as a CSV file.
city_data_df.to_csv(output_data_file, index_label="City_ID")
