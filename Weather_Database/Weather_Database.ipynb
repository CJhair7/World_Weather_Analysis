# %%
# Importing the randon module
import random

# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
#lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates  = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities= []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Import the requests library.
import requests

# Import the API key.
from conf import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
import pprint

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
#     print(city_url)
#     break

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
#         pprint.pprint(city_weather)
#         break
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | coquimbo
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | taganak
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | antalaha
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | kruisfontein
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | dudinka
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | poum
# Processing Record 16 of Set 1 | taltal
# Processing Record 17 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 19 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 1 | rumoi
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | camacha
# Processing Record 25 of Set 1 | northam
# Processing Record 26 of Set 1 | balakhta
# Processing Record 27 of Set 1 | flin flon
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | nuevitas
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | san ramon
# Processing Record 34 of Set 1 | arlit
# Processing Record 35 of Set 1 | varde
# Processing Record 36 of Set 1 | cidreira
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | maldonado
# Processing Record 39 of Set 1 | watsa
# Processing Record 40 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 1 | clarence town
# Processing Record 42 of Set 1 | kautokeino
# Processing Record 43 of Set 1 | sibolga
# Processing Record 44 of Set 1 | narsaq
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | shieli
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | malmesbury
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | souillac
# Processing Record 3 of Set 2 | wonthaggi
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | ziro
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | saldanha
# Processing Record 9 of Set 2 | beisfjord
# Processing Record 10 of Set 2 | dzaoudzi
# Processing Record 11 of Set 2 | yeppoon
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | qinhuangdao
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | grindavik
# Processing Record 16 of Set 2 | dolores
# Processing Record 17 of Set 2 | iracoubo
# Processing Record 18 of Set 2 | byron bay
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | luderitz
# Processing Record 21 of Set 2 | walvis bay
# Processing Record 22 of Set 2 | xinzhou
# Processing Record 23 of Set 2 | sayyan
# Processing Record 24 of Set 2 | isangel
# Processing Record 25 of Set 2 | padang
# Processing Record 26 of Set 2 | san cristobal
# Processing Record 27 of Set 2 | plettenberg bay
# Processing Record 28 of Set 2 | abha
# Processing Record 29 of Set 2 | ust-nera
# Processing Record 30 of Set 2 | port lincoln
# Processing Record 31 of Set 2 | bela
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | romitan
# Processing Record 34 of Set 2 | nyurba
# Processing Record 35 of Set 2 | lincoln
# Processing Record 36 of Set 2 | usinsk
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | nara
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | airai
# Processing Record 41 of Set 2 | hasaki
# Processing Record 42 of Set 2 | cherskiy
# Processing Record 43 of Set 2 | havre-saint-pierre
# Processing Record 44 of Set 2 | sangar
# Processing Record 45 of Set 2 | komsomolskiy
# Processing Record 46 of Set 2 | bambanglipuro
# Processing Record 47 of Set 2 | schleswig
# Processing Record 48 of Set 2 | saskylakh
# Processing Record 49 of Set 2 | pisco
# Processing Record 50 of Set 2 | auki
# Processing Record 1 of Set 3 | desaguadero
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | san patricio
# Processing Record 4 of Set 3 | ushuaia
# Processing Record 5 of Set 3 | aksu
# Processing Record 6 of Set 3 | abu samrah
# Processing Record 7 of Set 3 | berbera
# Processing Record 8 of Set 3 | mizdah
# Processing Record 9 of Set 3 | lebu
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | okrisky
# Processing Record 12 of Set 3 | ribeira grande
# Processing Record 13 of Set 3 | vardo
# Processing Record 14 of Set 3 | namibe
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | ponta do sol
# Processing Record 17 of Set 3 | provideniya
# Processing Record 18 of Set 3 | mount gambier
# Processing Record 19 of Set 3 | charlestown
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | atar
# Processing Record 23 of Set 3 | rognan
# Processing Record 24 of Set 3 | ishigaki
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | geraldton
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | wuxi
# Processing Record 29 of Set 3 | carnarvon
# Processing Record 30 of Set 3 | mitsamiouli
# Processing Record 31 of Set 3 | hithadhoo
# Processing Record 32 of Set 3 | half moon bay
# Processing Record 33 of Set 3 | terrace
# Processing Record 34 of Set 3 | sinnamary
# Processing Record 35 of Set 3 | charters towers
# Processing Record 36 of Set 3 | palmer
# Processing Record 37 of Set 3 | cockburn town
# Processing Record 38 of Set 3 | mwingi
# Processing Record 39 of Set 3 | clyde river
# Processing Record 40 of Set 3 | mar del plata
# Processing Record 41 of Set 3 | mahebourg
# Processing Record 42 of Set 3 | suba
# Processing Record 43 of Set 3 | mezen
# Processing Record 44 of Set 3 | miri
# Processing Record 45 of Set 3 | khasan
# Processing Record 46 of Set 3 | faanui
# Processing Record 47 of Set 3 | upernavik
# Processing Record 48 of Set 3 | fortuna
# Processing Record 49 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 3 | kushmurun
# Processing Record 1 of Set 4 | kosh-agach
# Processing Record 2 of Set 4 | chuy
# Processing Record 3 of Set 4 | general pico
# Processing Record 4 of Set 4 | tuktoyaktuk
# Processing Record 5 of Set 4 | la palma
# Processing Record 6 of Set 4 | praia
# Processing Record 7 of Set 4 | new norfolk
# Processing Record 8 of Set 4 | bonthe
# Processing Record 9 of Set 4 | kalmunai
# Processing Record 10 of Set 4 | klaksvik
# Processing Record 11 of Set 4 | saint george
# Processing Record 12 of Set 4 | trat
# Processing Record 13 of Set 4 | puro
# Processing Record 14 of Set 4 | bardiyah
# Processing Record 15 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 4 | leningradskiy
# Processing Record 17 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 18 of Set 4 | progreso
# Processing Record 19 of Set 4 | innisfail
# Processing Record 20 of Set 4 | rabaul
# Processing Record 21 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 4 | cholan
# City not found. Skipping...
# Processing Record 24 of Set 4 | vao
# Processing Record 25 of Set 4 | cabo san lucas
# Processing Record 26 of Set 4 | thessalon
# Processing Record 27 of Set 4 | akhalgori
# Processing Record 28 of Set 4 | pemba
# Processing Record 29 of Set 4 | verkhoyansk
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | saint-francois
# Processing Record 32 of Set 4 | shamary
# Processing Record 33 of Set 4 | ozinki
# Processing Record 34 of Set 4 | te anau
# Processing Record 35 of Set 4 | san quintin
# Processing Record 36 of Set 4 | chokurdakh
# Processing Record 37 of Set 4 | chisec
# Processing Record 38 of Set 4 | kunming
# Processing Record 39 of Set 4 | kutum
# Processing Record 40 of Set 4 | leeton
# Processing Record 41 of Set 4 | chuchkovo
# Processing Record 42 of Set 4 | katsuura
# Processing Record 43 of Set 4 | niamtougou
# Processing Record 44 of Set 4 | bryan
# Processing Record 45 of Set 4 | zabaykalsk
# Processing Record 46 of Set 4 | hamilton
# Processing Record 47 of Set 4 | inuvik
# Processing Record 48 of Set 4 | yarada
# Processing Record 49 of Set 4 | salta
# Processing Record 50 of Set 4 | male
# Processing Record 1 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 5 | tiksi
# Processing Record 3 of Set 5 | olga
# Processing Record 4 of Set 5 | aklavik
# Processing Record 5 of Set 5 | nome
# Processing Record 6 of Set 5 | monrovia
# Processing Record 7 of Set 5 | sisimiut
# Processing Record 8 of Set 5 | saint anthony
# Processing Record 9 of Set 5 | tarko-sale
# Processing Record 10 of Set 5 | valparaiso
# Processing Record 11 of Set 5 | cayenne
# Processing Record 12 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 5 | mecca
# Processing Record 14 of Set 5 | lerwick
# Processing Record 15 of Set 5 | eydhafushi
# Processing Record 16 of Set 5 | arbuzynka
# Processing Record 17 of Set 5 | tecoanapa
# Processing Record 18 of Set 5 | odienne
# Processing Record 19 of Set 5 | nouadhibou
# Processing Record 20 of Set 5 | blois
# Processing Record 21 of Set 5 | severo-kurilsk
# Processing Record 22 of Set 5 | grand gaube
# Processing Record 23 of Set 5 | novikovo
# Processing Record 24 of Set 5 | garissa
# Processing Record 25 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 5 | nantucket
# Processing Record 27 of Set 5 | araguacu
# Processing Record 28 of Set 5 | umm lajj
# Processing Record 29 of Set 5 | nizhniy baskunchak
# Processing Record 30 of Set 5 | obo
# Processing Record 31 of Set 5 | dicabisagan
# Processing Record 32 of Set 5 | comonfort
# Processing Record 33 of Set 5 | marsa matruh
# Processing Record 34 of Set 5 | ibra
# Processing Record 35 of Set 5 | bubaque
# Processing Record 36 of Set 5 | tanout
# Processing Record 37 of Set 5 | sorong
# Processing Record 38 of Set 5 | ilulissat
# Processing Record 39 of Set 5 | xai-xai
# Processing Record 40 of Set 5 | tarakan
# Processing Record 41 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 5 | college
# Processing Record 43 of Set 5 | tuatapere
# Processing Record 44 of Set 5 | banda aceh
# Processing Record 45 of Set 5 | voznesenskoye
# Processing Record 46 of Set 5 | hualmay
# Processing Record 47 of Set 5 | alofi
# Processing Record 48 of Set 5 | kaeo
# Processing Record 49 of Set 5 | saint-pierre
# Processing Record 50 of Set 5 | maningrida
# Processing Record 1 of Set 6 | togur
# Processing Record 2 of Set 6 | suao
# City not found. Skipping...
# Processing Record 3 of Set 6 | san joaquin
# Processing Record 4 of Set 6 | fukue
# Processing Record 5 of Set 6 | salinas
# Processing Record 6 of Set 6 | kaitangata
# Processing Record 7 of Set 6 | benito juarez
# Processing Record 8 of Set 6 | doka
# Processing Record 9 of Set 6 | kashi
# Processing Record 10 of Set 6 | buraydah
# Processing Record 11 of Set 6 | kabompo
# Processing Record 12 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 6 | cabra
# Processing Record 14 of Set 6 | tahta
# Processing Record 15 of Set 6 | hervey bay
# Processing Record 16 of Set 6 | lebedinyy
# Processing Record 17 of Set 6 | codrington
# Processing Record 18 of Set 6 | dire dawa
# Processing Record 19 of Set 6 | thompson
# Processing Record 20 of Set 6 | syedove
# Processing Record 21 of Set 6 | ler
# Processing Record 22 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 6 | laguna
# Processing Record 24 of Set 6 | beaumont
# Processing Record 25 of Set 6 | sergeyevka
# Processing Record 26 of Set 6 | portland
# Processing Record 27 of Set 6 | honiara
# Processing Record 28 of Set 6 | venado tuerto
# Processing Record 29 of Set 6 | uarini
# Processing Record 30 of Set 6 | lorengau
# Processing Record 31 of Set 6 | barhi
# Processing Record 32 of Set 6 | rio gallegos
# Processing Record 33 of Set 6 | galle
# Processing Record 34 of Set 6 | walla walla
# Processing Record 35 of Set 6 | brownsville
# Processing Record 36 of Set 6 | zyryanka
# Processing Record 37 of Set 6 | socorro
# Processing Record 38 of Set 6 | ancud
# Processing Record 39 of Set 6 | benghazi
# Processing Record 40 of Set 6 | bilibino
# Processing Record 41 of Set 6 | pringsewu
# Processing Record 42 of Set 6 | ixtapa
# Processing Record 43 of Set 6 | richards bay
# Processing Record 44 of Set 6 | guerrero negro
# Processing Record 45 of Set 6 | sovetskaya gavan
# Processing Record 46 of Set 6 | kupang
# Processing Record 47 of Set 6 | rudbar
# Processing Record 48 of Set 6 | cap malheureux
# Processing Record 49 of Set 6 | abu jubayhah
# City not found. Skipping...
# Processing Record 50 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 7 | lamu
# Processing Record 2 of Set 7 | quang ngai
# Processing Record 3 of Set 7 | providencia
# Processing Record 4 of Set 7 | sabang
# Processing Record 5 of Set 7 | khatanga
# Processing Record 6 of Set 7 | pevek
# Processing Record 7 of Set 7 | lazaro cardenas
# Processing Record 8 of Set 7 | amarante do maranhao
# Processing Record 9 of Set 7 | beloha
# Processing Record 10 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 7 | erzin
# Processing Record 12 of Set 7 | kieta
# Processing Record 13 of Set 7 | baruun-urt
# Processing Record 14 of Set 7 | kavaratti
# Processing Record 15 of Set 7 | nichinan
# Processing Record 16 of Set 7 | creel
# Processing Record 17 of Set 7 | ostrovnoy
# Processing Record 18 of Set 7 | husavik
# Processing Record 19 of Set 7 | sohag
# Processing Record 20 of Set 7 | oranjemund
# Processing Record 21 of Set 7 | huzhou
# Processing Record 22 of Set 7 | iisalmi
# Processing Record 23 of Set 7 | pundaguitan
# Processing Record 24 of Set 7 | logansport
# Processing Record 25 of Set 7 | muros
# Processing Record 26 of Set 7 | lavrentiya
# Processing Record 27 of Set 7 | tiznit
# Processing Record 28 of Set 7 | sao jose da coroa grande
# Processing Record 29 of Set 7 | korla
# Processing Record 30 of Set 7 | coahuayana
# Processing Record 31 of Set 7 | the pas
# Processing Record 32 of Set 7 | zhangye
# Processing Record 33 of Set 7 | sand springs
# Processing Record 34 of Set 7 | srednekolymsk
# Processing Record 35 of Set 7 | kahului
# Processing Record 36 of Set 7 | chara
# Processing Record 37 of Set 7 | dhidhdhoo
# Processing Record 38 of Set 7 | kavieng
# Processing Record 39 of Set 7 | channel-port aux basques
# Processing Record 40 of Set 7 | sur
# Processing Record 41 of Set 7 | peniche
# Processing Record 42 of Set 7 | kloulklubed
# Processing Record 43 of Set 7 | vila velha
# Processing Record 44 of Set 7 | maceio
# Processing Record 45 of Set 7 | bam
# Processing Record 46 of Set 7 | samfya
# Processing Record 47 of Set 7 | jian
# Processing Record 48 of Set 7 | coihaique
# Processing Record 49 of Set 7 | cabedelo
# Processing Record 50 of Set 7 | raymond
# Processing Record 1 of Set 8 | paamiut
# Processing Record 2 of Set 8 | aripuana
# Processing Record 3 of Set 8 | le lamentin
# Processing Record 4 of Set 8 | borsa
# Processing Record 5 of Set 8 | soyo
# Processing Record 6 of Set 8 | honningsvag
# Processing Record 7 of Set 8 | pandanon
# City not found. Skipping...
# Processing Record 8 of Set 8 | hofn
# Processing Record 9 of Set 8 | fushe-arrez
# Processing Record 10 of Set 8 | balkanabat
# Processing Record 11 of Set 8 | homer
# Processing Record 12 of Set 8 | svetlyy
# Processing Record 13 of Set 8 | kurilsk
# Processing Record 14 of Set 8 | sao filipe
# Processing Record 15 of Set 8 | beni
# Processing Record 16 of Set 8 | keti bandar
# Processing Record 17 of Set 8 | margate
# Processing Record 18 of Set 8 | ukiah
# Processing Record 19 of Set 8 | bouake
# Processing Record 20 of Set 8 | bengkulu
# Processing Record 21 of Set 8 | juegang
# Processing Record 22 of Set 8 | touros
# Processing Record 23 of Set 8 | burns lake
# Processing Record 24 of Set 8 | chapais
# Processing Record 25 of Set 8 | pangkalanbuun
# Processing Record 26 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 8 | hun
# Processing Record 28 of Set 8 | sinaloa
# Processing Record 29 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 30 of Set 8 | zhaotong
# Processing Record 31 of Set 8 | samarai
# Processing Record 32 of Set 8 | high rock
# Processing Record 33 of Set 8 | luoyang
# Processing Record 34 of Set 8 | luganville
# Processing Record 35 of Set 8 | saint combs
# City not found. Skipping...
# Processing Record 36 of Set 8 | zaysan
# Processing Record 37 of Set 8 | paracambi
# Processing Record 38 of Set 8 | zlobin
# Processing Record 39 of Set 8 | ormara
# Processing Record 40 of Set 8 | naze
# Processing Record 41 of Set 8 | brainerd
# Processing Record 42 of Set 8 | tessalit
# Processing Record 43 of Set 8 | kouroussa
# Processing Record 44 of Set 8 | olafsvik
# Processing Record 45 of Set 8 | stryn
# Processing Record 46 of Set 8 | norman wells
# Processing Record 47 of Set 8 | green river
# Processing Record 48 of Set 8 | astoria
# Processing Record 49 of Set 8 | constitucion
# Processing Record 50 of Set 8 | mehamn
# Processing Record 1 of Set 9 | fort nelson
# Processing Record 2 of Set 9 | khanpur
# Processing Record 3 of Set 9 | ballina
# Processing Record 4 of Set 9 | hurricane
# Processing Record 5 of Set 9 | kasongo-lunda
# Processing Record 6 of Set 9 | arcata
# Processing Record 7 of Set 9 | xining
# Processing Record 8 of Set 9 | vostok
# Processing Record 9 of Set 9 | thinadhoo
# Processing Record 10 of Set 9 | whitehorse
# Processing Record 11 of Set 9 | verkhnevilyuysk
# Processing Record 12 of Set 9 | vanavara
# Processing Record 13 of Set 9 | kudahuvadhoo
# Processing Record 14 of Set 9 | namatanai
# Processing Record 15 of Set 9 | cayhagan
# Processing Record 16 of Set 9 | deputatskiy
# Processing Record 17 of Set 9 | bintulu
# Processing Record 18 of Set 9 | baykit
# Processing Record 19 of Set 9 | banmankhi
# Processing Record 20 of Set 9 | jalu
# Processing Record 21 of Set 9 | vaitape
# Processing Record 22 of Set 9 | odda
# Processing Record 23 of Set 9 | los llanos de aridane
# Processing Record 24 of Set 9 | suicheng
# Processing Record 25 of Set 9 | severodvinsk
# Processing Record 26 of Set 9 | yingcheng
# Processing Record 27 of Set 9 | esperance
# Processing Record 28 of Set 9 | angoche
# Processing Record 29 of Set 9 | kolokani
# Processing Record 30 of Set 9 | pontianak
# Processing Record 31 of Set 9 | amapa
# Processing Record 32 of Set 9 | nemuro
# Processing Record 33 of Set 9 | kousseri
# Processing Record 34 of Set 9 | nanortalik
# Processing Record 35 of Set 9 | ravar
# Processing Record 36 of Set 9 | shimoda
# Processing Record 37 of Set 9 | yashkul
# Processing Record 38 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 9 | rubtsovsk
# Processing Record 40 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 9 | lingyuan
# Processing Record 42 of Set 9 | plover
# Processing Record 43 of Set 9 | longyearbyen
# Processing Record 44 of Set 9 | matay
# Processing Record 45 of Set 9 | gat
# Processing Record 46 of Set 9 | puerto escondido
# Processing Record 47 of Set 9 | puyang
# Processing Record 48 of Set 9 | ayan
# Processing Record 49 of Set 9 | westport
# Processing Record 50 of Set 9 | virginia beach
# Processing Record 1 of Set 10 | mechanicsville
# Processing Record 2 of Set 10 | nouakchott
# Processing Record 3 of Set 10 | pathein
# Processing Record 4 of Set 10 | bogovarovo
# Processing Record 5 of Set 10 | abdanan
# Processing Record 6 of Set 10 | manzanillo
# Processing Record 7 of Set 10 | gold coast
# Processing Record 8 of Set 10 | bud
# Processing Record 9 of Set 10 | nagato
# Processing Record 10 of Set 10 | riyadh
# Processing Record 11 of Set 10 | severnyy
# Processing Record 12 of Set 10 | karratha
# Processing Record 13 of Set 10 | standerton
# Processing Record 14 of Set 10 | marsaxlokk
# Processing Record 15 of Set 10 | lagoa
# Processing Record 16 of Set 10 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 17 of Set 10 | luena
# Processing Record 18 of Set 10 | urumqi
# Processing Record 19 of Set 10 | bor
# Processing Record 20 of Set 10 | kem
# Processing Record 21 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 22 of Set 10 | ipanguacu
# Processing Record 23 of Set 10 | buala
# Processing Record 24 of Set 10 | bandarbeyla
# Processing Record 25 of Set 10 | santa cruz
# Processing Record 26 of Set 10 | trincomalee
# Processing Record 27 of Set 10 | aromashevo
# Processing Record 28 of Set 10 | pokhara
# Processing Record 29 of Set 10 | eyl
# Processing Record 30 of Set 10 | mandera
# Processing Record 31 of Set 10 | borovoy
# Processing Record 32 of Set 10 | enshi
# Processing Record 33 of Set 10 | never
# Processing Record 34 of Set 10 | nsanje
# Processing Record 35 of Set 10 | hirado
# Processing Record 36 of Set 10 | port blair
# Processing Record 37 of Set 10 | yumen
# Processing Record 38 of Set 10 | acarau
# Processing Record 39 of Set 10 | inongo
# Processing Record 40 of Set 10 | aykhal
# Processing Record 41 of Set 10 | sorland
# Processing Record 42 of Set 10 | whithorn
# Processing Record 43 of Set 10 | dingle
# Processing Record 44 of Set 10 | pemangkat
# Processing Record 45 of Set 10 | manta
# Processing Record 46 of Set 10 | svetlogorsk
# Processing Record 47 of Set 10 | eufaula
# Processing Record 48 of Set 10 | tashara
# Processing Record 49 of Set 10 | neuquen
# Processing Record 50 of Set 10 | vestmannaeyjar
# Processing Record 1 of Set 11 | hoskote
# Processing Record 2 of Set 11 | phalaborwa
# Processing Record 3 of Set 11 | iqaluit
# Processing Record 4 of Set 11 | biltine
# Processing Record 5 of Set 11 | teya
# Processing Record 6 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 11 | porto velho
# Processing Record 8 of Set 11 | shitanjing
# Processing Record 9 of Set 11 | rocha
# Processing Record 10 of Set 11 | imbituba
# Processing Record 11 of Set 11 | victoria
# Processing Record 12 of Set 11 | tete
# Processing Record 13 of Set 11 | opuwo
# Processing Record 14 of Set 11 | rockledge
# Processing Record 15 of Set 11 | vila franca do campo
# Processing Record 16 of Set 11 | flinders
# Processing Record 17 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 11 | pochutla
# Processing Record 19 of Set 11 | akyab
# Processing Record 20 of Set 11 | launceston
# Processing Record 21 of Set 11 | kushima
# Processing Record 22 of Set 11 | rio grande
# Processing Record 23 of Set 11 | sibenik
# Processing Record 24 of Set 11 | lompoc
# Processing Record 25 of Set 11 | concepcion del oro
# Processing Record 26 of Set 11 | caico
# Processing Record 27 of Set 11 | kehl
# Processing Record 28 of Set 11 | aurad
# Processing Record 29 of Set 11 | bednodemyanovsk
# City not found. Skipping...
# Processing Record 30 of Set 11 | can tho
# Processing Record 31 of Set 11 | banes
# Processing Record 32 of Set 11 | acapulco
# Processing Record 33 of Set 11 | mogadouro
# Processing Record 34 of Set 11 | alta floresta
# Processing Record 35 of Set 11 | pangai
# Processing Record 36 of Set 11 | tomatlan
# Processing Record 37 of Set 11 | san carlos de bariloche
# Processing Record 38 of Set 11 | ca mau
# Processing Record 39 of Set 11 | kerema
# Processing Record 40 of Set 11 | mackenzie
# Processing Record 41 of Set 11 | sioux lookout
# Processing Record 42 of Set 11 | dholka
# Processing Record 43 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 44 of Set 11 | buin
# Processing Record 45 of Set 11 | boa vista
# Processing Record 46 of Set 11 | ewa beach
# Processing Record 47 of Set 11 | monroe
# Processing Record 48 of Set 11 | krasnoselkup
# Processing Record 49 of Set 11 | valdivia
# Processing Record 50 of Set 11 | itarema
# Processing Record 1 of Set 12 | north platte
# Processing Record 2 of Set 12 | visby
# Processing Record 3 of Set 12 | hami
# Processing Record 4 of Set 12 | pacific grove
# Processing Record 5 of Set 12 | kidal
# Processing Record 6 of Set 12 | spearfish
# Processing Record 7 of Set 12 | nizhnyaya tura
# Processing Record 8 of Set 12 | broome
# Processing Record 9 of Set 12 | minsk
# Processing Record 10 of Set 12 | cravo norte
# Processing Record 11 of Set 12 | huilong
# Processing Record 12 of Set 12 | ahuimanu
# Processing Record 13 of Set 12 | sao felipe
# Processing Record 14 of Set 12 | nishihara
# Processing Record 15 of Set 12 | sao joao da barra
# Processing Record 16 of Set 12 | okakarara
# Processing Record 17 of Set 12 | murmashi
# Processing Record 18 of Set 12 | tilichiki
# Processing Record 19 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 12 | dillon
# Processing Record 21 of Set 12 | barcelos
# Processing Record 22 of Set 12 | vila do maio
# Processing Record 23 of Set 12 | novobiryusinskiy
# Processing Record 24 of Set 12 | chino valley
# Processing Record 25 of Set 12 | pozo colorado
# Processing Record 26 of Set 12 | stromness
# Processing Record 27 of Set 12 | indiaroba
# Processing Record 28 of Set 12 | liverpool
# Processing Record 29 of Set 12 | lakes entrance
# Processing Record 30 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 12 | okhotsk
# Processing Record 32 of Set 12 | shingu
# Processing Record 33 of Set 12 | bourail
# Processing Record 34 of Set 12 | prainha
# Processing Record 35 of Set 12 | beringovskiy
# Processing Record 36 of Set 12 | hohhot
# Processing Record 37 of Set 12 | atlantic city
# Processing Record 38 of Set 12 | kholbon
# Processing Record 39 of Set 12 | tautira
# Processing Record 40 of Set 12 | sao goncalo do amarante
# Processing Record 41 of Set 12 | mitchell
# Processing Record 42 of Set 12 | torbay
# Processing Record 43 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 12 | ndele
# Processing Record 46 of Set 12 | vangaindrano
# Processing Record 47 of Set 12 | aksarka
# Processing Record 48 of Set 12 | san pedro
# Processing Record 49 of Set 12 | benjamin aceval
# Processing Record 50 of Set 12 | kohima
# Processing Record 1 of Set 13 | mazagao
# Processing Record 2 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 13 | murray bridge
# Processing Record 4 of Set 13 | tabarqah
# City not found. Skipping...
# Processing Record 5 of Set 13 | agogo
# Processing Record 6 of Set 13 | manzhouli
# Processing Record 7 of Set 13 | nobres
# Processing Record 8 of Set 13 | salalah
# Processing Record 9 of Set 13 | rosetta
# Processing Record 10 of Set 13 | kadoma
# Processing Record 11 of Set 13 | nanakuli
# Processing Record 12 of Set 13 | meulaboh
# Processing Record 13 of Set 13 | brora
# Processing Record 14 of Set 13 | sosva
# Processing Record 15 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 13 | sonqor
# Processing Record 17 of Set 13 | zhezkazgan
# Processing Record 18 of Set 13 | san juan
# Processing Record 19 of Set 13 | karaton
# Processing Record 20 of Set 13 | harlingen
# Processing Record 21 of Set 13 | mariental
# Processing Record 22 of Set 13 | mount isa
# Processing Record 23 of Set 13 | yara
# Processing Record 24 of Set 13 | guaraniacu
# Processing Record 25 of Set 13 | manbij
# Processing Record 26 of Set 13 | viedma
# Processing Record 27 of Set 13 | osorno
# Processing Record 28 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 13 | zavyalovo
# Processing Record 30 of Set 13 | fayaoue
# Processing Record 31 of Set 13 | dawson
# Processing Record 32 of Set 13 | san ignacio
# Processing Record 33 of Set 13 | rosarito
# Processing Record 34 of Set 13 | merta
# Processing Record 35 of Set 13 | doha
# Processing Record 36 of Set 13 | puerto narino
# Processing Record 37 of Set 13 | sanica
# Processing Record 38 of Set 13 | ottumwa
# Processing Record 39 of Set 13 | kholmogory
# Processing Record 40 of Set 13 | pionerskiy
# Processing Record 41 of Set 13 | marienburg
# Processing Record 42 of Set 13 | skibbereen
# Processing Record 43 of Set 13 | beaverlodge
# Processing Record 44 of Set 13 | san jose
# Processing Record 45 of Set 13 | asau
# Processing Record 46 of Set 13 | parkent
# Processing Record 47 of Set 13 | fairbanks
# Processing Record 48 of Set 13 | marfino
# Processing Record 49 of Set 13 | puerto maldonado
# Processing Record 50 of Set 13 | qaqortoq
# Processing Record 1 of Set 14 | itiuba
# Processing Record 2 of Set 14 | winnemucca
# Processing Record 3 of Set 14 | romodanovo
# Processing Record 4 of Set 14 | cartagena
# Processing Record 5 of Set 14 | tierranueva
# Processing Record 6 of Set 14 | axim
# Processing Record 7 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 8 of Set 14 | tual
# Processing Record 9 of Set 14 | quime
# Processing Record 10 of Set 14 | stanari
# Processing Record 11 of Set 14 | saint-leu
# Processing Record 12 of Set 14 | khowai
# Processing Record 13 of Set 14 | ouadda
# Processing Record 14 of Set 14 | faya
# Processing Record 15 of Set 14 | kapit
# Processing Record 16 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 14 | kulhudhuffushi
# Processing Record 18 of Set 14 | steinbach
# Processing Record 19 of Set 14 | harper
# Processing Record 20 of Set 14 | presidencia roque saenz pena
# Processing Record 21 of Set 14 | mangai
# Processing Record 22 of Set 14 | asahikawa
# Processing Record 23 of Set 14 | kazerun
# Processing Record 24 of Set 14 | lichinga
# Processing Record 25 of Set 14 | ahipara
# Processing Record 26 of Set 14 | gudur
# Processing Record 27 of Set 14 | tommot
# Processing Record 28 of Set 14 | gizo
# Processing Record 29 of Set 14 | hirara
# Processing Record 30 of Set 14 | alenquer
# Processing Record 31 of Set 14 | sungaipenuh
# Processing Record 32 of Set 14 | kanata
# Processing Record 33 of Set 14 | necochea
# Processing Record 34 of Set 14 | sola
# Processing Record 35 of Set 14 | freeport
# Processing Record 36 of Set 14 | kadiri
# Processing Record 37 of Set 14 | arrifes
# Processing Record 38 of Set 14 | jiaojiang
# Processing Record 39 of Set 14 | port hardy
# Processing Record 40 of Set 14 | meadow lake
# Processing Record 41 of Set 14 | kargasok
# Processing Record 42 of Set 14 | lander
# Processing Record 43 of Set 14 | ajaccio
# Processing Record 44 of Set 14 | payo
# Processing Record 45 of Set 14 | ust-tsilma
# Processing Record 46 of Set 14 | tallahassee
# Processing Record 47 of Set 14 | brae
# Processing Record 48 of Set 14 | khotynets
# Processing Record 49 of Set 14 | chubbuck
# Processing Record 50 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 15 | kuryk
# Processing Record 2 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 15 | south lyon
# Processing Record 4 of Set 15 | szprotawa
# Processing Record 5 of Set 15 | moerai
# Processing Record 6 of Set 15 | taoudenni
# Processing Record 7 of Set 15 | tevaitoa
# Processing Record 8 of Set 15 | vabalninkas
# Processing Record 9 of Set 15 | artyom
# Processing Record 10 of Set 15 | arsenyev
# Processing Record 11 of Set 15 | la ronge
# Processing Record 12 of Set 15 | macrohon
# Processing Record 13 of Set 15 | sawang daen din
# Processing Record 14 of Set 15 | langsa
# Processing Record 15 of Set 15 | chiusi
# Processing Record 16 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 17 of Set 15 | san miguel
# Processing Record 18 of Set 15 | warwick
# Processing Record 19 of Set 15 | hovd
# Processing Record 20 of Set 15 | grao mogol
# Processing Record 21 of Set 15 | chenghai
# Processing Record 22 of Set 15 | belaya gora
# Processing Record 23 of Set 15 | hays
# Processing Record 24 of Set 15 | turukhansk
# Processing Record 25 of Set 15 | batticaloa
# Processing Record 26 of Set 15 | golega
# Processing Record 27 of Set 15 | santa rosa
# Processing Record 28 of Set 15 | miraflores
# Processing Record 29 of Set 15 | pindi bhattian
# Processing Record 30 of Set 15 | mahon
# Processing Record 31 of Set 15 | yar-sale
# Processing Record 32 of Set 15 | vieques
# Processing Record 33 of Set 15 | hutchinson
# Processing Record 34 of Set 15 | mongo
# Processing Record 35 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 15 | kenai
# Processing Record 37 of Set 15 | vestmanna
# Processing Record 38 of Set 15 | aljezur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Coquimbo -29.9533  -71.3436     59.07        84          57
# 1        Cape Town -33.9258   18.4232     60.28        93          75
# 2          Mataura -46.1927  168.8643     56.48        41          77
# 3          Taganak   6.0833  118.3000     84.34        74          97
# 4   Saint-Philippe -21.3585   55.7679     80.15        74          29
# 5  Arraial Do Cabo -22.9661  -42.0278     73.87        90          58
# 6         Antalaha -14.9003   50.2788     75.67        81          15
# 7        Busselton -33.6500  115.3333     66.09        45          43
# 8     Kruisfontein -34.0033   24.7314     61.88        88          73
# 9      Port Alfred -33.5906   26.8910     66.49        93          77
#
#    Wind Speed Country      Current Description
# 0        2.89      CL            broken clouds
# 1        1.01      ZA  light intensity drizzle
# 2        8.43      NZ            broken clouds
# 3        4.41      PH          overcast clouds
# 4        8.97      RE         scattered clouds
# 5       18.16      BR            moderate rain
# 6        5.21      MG               few clouds
# 7       12.39      AU         scattered clouds
# 8       15.64      ZA            broken clouds
# 9       23.51      ZA               light rain

# %%
#change order of columns
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_order]
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Coquimbo      CL -29.9533  -71.3436     59.07        84          57
# 1       Cape Town      ZA -33.9258   18.4232     60.28        93          75
# 2         Mataura      NZ -46.1927  168.8643     56.48        41          77
# 3         Taganak      PH   6.0833  118.3000     84.34        74          97
# 4  Saint-Philippe      RE -21.3585   55.7679     80.15        74          29
#
#    Wind Speed      Current Description
# 0        2.89            broken clouds
# 1        1.01  light intensity drizzle
# 2        8.43            broken clouds
# 3        4.41          overcast clouds
# 4        8.97         scattered clouds

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the Data Frame as a CSV file.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-1846638bc8ae> in <module>
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       3 # Export the Data Frame as a CSV file.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3401             doublequote=doublequote,
#    3402             escapechar=escapechar,
# -> 3403             storage_options=storage_options,
#    3404         )
#    3405
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     232             errors=self.errors,
#     233             compression=self.compression,
# --> 234             storage_options=self.storage_options,
#     235         ) as handles:
#     236
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
